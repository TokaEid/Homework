# %% [markdown]
# # Answers

# %%
import functions # this is the functions module you are writing
import numpy as np
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Warning
#
# Jupyter notebooks can be tricky with `git`, especially when multiple people are working on them.  Most of the work in this assignment is in completing `functions.py`, but you may want to be careful to have this notebook backed up before doing any merges so its contents don't get lost.

# %% [markdown]
# ## Group Information
#
# Briefly state your names, and who did what in the assignment. You can replace the following information:
#
# **Toka Eid** - P0 part A, B, D, E, and F
#
# **Yanhao Dong** - P1
#
# **Zhengjie Xiong** - P0 part C and P2

# %% [markdown]
# ## Demo
#
# Note that the way that `__call__` evaluates on strings in `AbstractFunction` lets you do the following:

# %%
from functions import Polynomial
p = Polynomial(2,1,1) # 2 x^2 + x + 1
print(p)      # print Polynomail
print(p(1))   # call evaluates polynomial at 1
print(p('x')) # call formats print string with 'x'
# Out:
# 2({0})^2 + {0} + 1
# 4
# 2(x)^2 + x + 1

# %% [markdown]
# you can do the same with

# %%
str(p).format('y') # use 'y' instead of 'x'
# Out:
# '2(y)^2 + y + 1'

# %% [markdown]
# # Problem 0
#
# ## Part A
#
# You might want to write something under these headers if you want to explain anything

# %%
from functions import Polynomial

p = Polynomial(5,3,1)
p.plot(color='red')

# %% [markdown]
# ## Part B

# %%
from functions import Scale, Constant

Scale(2).plot(color='blue')
Constant(1).plot(color="green")

# %% [markdown]
# ## Part C

# %%
from functions import Polynomial, Compose

Compose(Polynomial(1,0,0), Polynomial(1,0,0)).plot()
print(Compose(Polynomial(1,0,0), Polynomial(1,0,0)))
# Out:
# (({0})^2)^2

# %% [markdown]
# ## Part D

# %%
from functions import Power

print(Power(-1))
Power(-1).plot(vals=np.linspace(0.05,5,100), color='red')
# Out:
# 1*({0})^-1

# %%
from functions import Log

print(Log(2))
Log(2).plot(vals=np.linspace(0.01,10,100),color='blue')
# Out:
# 1*log[2*{0}]

# %%
from functions import Exponential

print(Exponential(4,2))
Exponential(4,2).plot(color='purple')
# Out:
# 2*exp[4*{0}]

# %%
from functions import Sin

print(Sin(3))
Sin(3).plot(vals=np.linspace(0,5,100),color='orange')
# Out:
# 1*sin[3*{0}]

# %%
from functions import Cos

print(Cos(2))
Cos(2).plot(vals=np.linspace(0,5,100),color='magenta')
# Out:
# 1*cos[2*{0}]

# %% [markdown]
# ## Part E

# %%
from functions import Symbolic, Product

print(Product(Symbolic('f'),Symbolic('g')).derivative())
# Out:
# f'({0}) * g({0}) + f({0}) * g'({0})

# %% [markdown]
# ## Part F

# %% [markdown]
# 1. What is the derivative of `5x^2 + 3x + 1`?

# %%
from functions import Polynomial

print(Polynomial(5,3,1).derivative())
# Out:
# 10({0}) + 3

# %% [markdown]
# 2. Derive a rule for the derivative of $f = g/h$ using symbolic functions.  Does this reduce to quotient rule?

# %%
from functions import Symbolic, Power, Product, Compose

print(Product(Symbolic('g'),Compose(Power(-1),Symbolic('h'))).derivative())
# Out:
# g'({0}) * 1*(h({0}))^-1 + g({0}) * -1*(h({0}))^-2 * h'({0})

# %% [markdown]
# 3. What is the derivative of $\sin(x)^2$?

# %%
from functions import Compose, Sin, Power

print(Compose(Power(2),Sin()).derivative())
# Out:
# 2*(1*sin[1*{0}])^1 * 1*cos[1*{0}]

# %% [markdown]
# 4. What is the second derivative of $e^{5x}$?

# %%
from functions import Exponential

print(Exponential(5).derivative().derivative())
# Out:
# 25*exp[5*{0}]

# %% [markdown]
# # Problem 1
#
# ## Part A

# %%
## Your code here
from functions import Sin, Exponential, Compose
import numpy as np
import matplotlib.pyplot as plt

f = Compose(Sin(), Exponential())
res = newton_root(f,1.0)

fig = plt.figure(figsize=(12,8))
plt.scatter(res,f(res))
f.plot(vals=np.linspace(0,5,100),color='magenta')
plt.show()

# %% [markdown]
# ## Part B

# %%
## Your code here
from functions import Sin, Exponential, Compose
import numpy as np
import matplotlib.pyplot as plt

f = Compose(Sin(), Exponential())
res = newton_extremum(f,0.0)

fig = plt.figure(figsize=(12,8))
plt.scatter(res,f(res))
f.plot(vals=np.linspace(0,-100,100),color='magenta')
plt.show()

# %% [markdown]
# # Problem 2
#
# ## Part A
#
# You don't need any code in this notebook - it goes in `functions.py`

# %% [markdown]
# ## Part B

# %%
s=Sin(1,1)
x=np.linspace(-3,3,21)
y1=s.taylor_series(x0=0,deg=0)(np.linspace(-3,3,21))
y2=s.taylor_series(x0=0,deg=1)(np.linspace(-3,3,21))
y3=s.taylor_series(x0=0,deg=3)(np.linspace(-3,3,21))
y4=s.taylor_series(x0=0,deg=5)(np.linspace(-3,3,21))
y5=s(np.linspace(-3,3,21))
plt.plot(x,y1,x,y2,x,y3,x,y4,x,y5)
plt.legend(["deg 0","deg 1", "deg 3", "deg 5","sin(x)"],loc="upper left")
plt.xlabel("range of sin(x)")
plt.ylabel("taylor series of sin(x) at x0=0")
plt.show()

# %% [markdown]
# # Feedback
